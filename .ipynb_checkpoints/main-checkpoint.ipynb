# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime
from datetime import date, timezone, timedelta
import pandas as pd
import numpy as np
import utils
import yfinance as yf
from spreads_prep import spreads_prep
from backtest import backtest
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
from datetimerange import DateTimeRange
import math
import gc
import os, glob

# %% [markdown]
# # Create option data by DTE
#
# If you want to generate spreads on specific DTE that is not included in the preload folder, please see the section below for codes. Otherwise, skip to the next section. With Core-i9 and DDR5, the average process time for generate one dataset range from 120s to 300s depending on your DTE setting. It requres around 10GB of RAM. The generated CSV files will be saved under OptionsData

# %%
# tk = 'SPY'
# df_stock = utils.OHLC_info_by_range(tk,'2005-01-01','2023-12-31',interval = '1d')
# st = df_stock.copy()
# path = 'OptionsData\\'
# _op = list()

# for filename in glob.glob(os.path.join(path + tk, '*.csv')):
#     _op.append(pd.read_csv(filename))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Start date: 2005-01-01
# End date: 2023-12-31
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))
# C:\Users\27270\AppData\Local\Temp\ipykernel_29704\1587516934.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   _op.append(pd.read_csv(filename))

# %%
# op = pd.concat(_op, ignore_index = True)
# class_prep = spreads_prep(op,st,DTE = list(range(45,120)))
# Out:
# Done Cleaning Data! CPU time: 23.50 seconds, Total time: 55.26 seconds
# Done Calculating Probability! CPU time: 2.50 seconds, Total time: 5.94 seconds
# Done Calculating Spreads with DTE = 45! CPU time: 166.20 seconds, Total time: 352.14 seconds
# Done Calculating Spreads with DTE = 46! CPU time: 135.73 seconds, Total time: 306.43 seconds
# Done Calculating Spreads with DTE = 47! CPU time: 6.77 seconds, Total time: 15.74 seconds
# Done Calculating Spreads with DTE = 48! CPU time: 13.88 seconds, Total time: 35.67 seconds
# Done Calculating Spreads with DTE = 49! CPU time: 152.17 seconds, Total time: 334.66 seconds
# Done Calculating Spreads with DTE = 50! CPU time: 134.34 seconds, Total time: 299.07 seconds
# Done Calculating Spreads with DTE = 51! CPU time: 119.19 seconds, Total time: 270.18 seconds
# Done Calculating Spreads with DTE = 52! CPU time: 117.16 seconds, Total time: 269.26 seconds
# Done Calculating Spreads with DTE = 53! CPU time: 110.73 seconds, Total time: 249.64 seconds
# Done Calculating Spreads with DTE = 54! CPU time: 8.34 seconds, Total time: 18.29 seconds
# Done Calculating Spreads with DTE = 55! CPU time: 12.88 seconds, Total time: 33.17 seconds
# Done Calculating Spreads with DTE = 56! CPU time: 119.16 seconds, Total time: 269.50 seconds
# Done Calculating Spreads with DTE = 57! CPU time: 121.56 seconds, Total time: 270.83 seconds
# Done Calculating Spreads with DTE = 58! CPU time: 113.75 seconds, Total time: 264.90 seconds
# Done Calculating Spreads with DTE = 59! CPU time: 123.98 seconds, Total time: 270.75 seconds
# Done Calculating Spreads with DTE = 60! CPU time: 97.34 seconds, Total time: 221.55 seconds
# Done Calculating Spreads with DTE = 61! CPU time: 11.23 seconds, Total time: 23.71 seconds
# Done Calculating Spreads with DTE = 62! CPU time: 15.17 seconds, Total time: 35.27 seconds
# Done Calculating Spreads with DTE = 63! CPU time: 129.45 seconds, Total time: 262.62 seconds
# Done Calculating Spreads with DTE = 97! CPU time: 7.91 seconds, Total time: 18.98 seconds
# Done Calculating Spreads with DTE = 98! CPU time: 81.64 seconds, Total time: 188.14 seconds
# Done Calculating Spreads with DTE = 99! CPU time: 83.08 seconds, Total time: 181.27 seconds
# Done Calculating Spreads with DTE = 100! CPU time: 75.92 seconds, Total time: 177.58 seconds
# Done Calculating Spreads with DTE = 101! CPU time: 64.47 seconds, Total time: 190.85 seconds
# Done Calculating Spreads with DTE = 102! CPU time: 27.81 seconds, Total time: 224.68 seconds
# Done Calculating Spreads with DTE = 103! CPU time: 1.59 seconds, Total time: 19.43 seconds
# Done Calculating Spreads with DTE = 104! CPU time: 3.16 seconds, Total time: 39.83 seconds
# Done Calculating Spreads with DTE = 105! CPU time: 27.56 seconds, Total time: 302.07 seconds
# Done Calculating Spreads with DTE = 106! CPU time: 37.64 seconds, Total time: 318.78 seconds
# Done Calculating Spreads with DTE = 107! CPU time: 22.28 seconds, Total time: 220.92 seconds
# Done Calculating Spreads with DTE = 108! CPU time: 50.47 seconds, Total time: 284.20 seconds
# Done Calculating Spreads with DTE = 109! CPU time: 47.41 seconds, Total time: 263.60 seconds
# Done Calculating Spreads with DTE = 110! CPU time: 3.38 seconds, Total time: 18.10 seconds
# Done Calculating Spreads with DTE = 111! CPU time: 6.94 seconds, Total time: 29.43 seconds
# Done Calculating Spreads with DTE = 112! CPU time: 68.27 seconds, Total time: 294.67 seconds
# Done Calculating Spreads with DTE = 113! CPU time: 39.45 seconds, Total time: 256.36 seconds
# Done Calculating Spreads with DTE = 114! CPU time: 61.95 seconds, Total time: 281.78 seconds
# Done Calculating Spreads with DTE = 115! CPU time: 49.30 seconds, Total time: 292.13 seconds
# Done Calculating Spreads with DTE = 116! CPU time: 48.22 seconds, Total time: 245.30 seconds
# Done Calculating Spreads with DTE = 117! CPU time: 1.69 seconds, Total time: 18.40 seconds
# Done Calculating Spreads with DTE = 118! CPU time: 4.83 seconds, Total time: 32.14 seconds
# Done Calculating Spreads with DTE = 119! CPU time: 22.14 seconds, Total time: 172.76 seconds

# %% [markdown]
# # Use preloaded spread data

# %%
op_cols = ['QuoteDate','Symbol', 'ExpirationDate', 'AskPrice', 'BidPrice','Dte'
           ,'PutCall', 'StrikePrice','UnderlyingPrice','OTM_Prob','ImpliedVolatility','ATM_IV','Price@Expiration']
op_cols2 = ['Symbol','QuoteDate', 'ExpirationDate', 'SellPrice', 'BuyPrice', 'Dte',
       'SellStrike', 'BuyStrike','UnderlyingPrice', 'Premium', 'MaxLoss', 'Sell_OTM_Prob', 'ExpectedEarnRatio', 'ExpectedEarn', 'Actual_Earn']
op_greeks = ['ImpliedVolatility', 'Delta','Gamma', 'Vega', 'Rho', 'Theta']

tk = 'SPY'
df_stock = utils.OHLC_info_by_range(tk,'2005-01-01','2023-12-31',interval = '1d')
st = df_stock.copy()

# %%
path = 'SpreadsData\\'
spread_type = 'Put' 
DTE = 14  #<-------- Set DTE here 
_sp = list()

for i in range(1,DTE+1):
    filename = path+ tk + '\\DTE' + str(i) + '_' + tk + '_' + spread_type + 'Spreads.csv'
    _sp.append(pd.read_csv(filename, index_col = 0))
# for filename in glob.glob(os.path.join(path + tk, '*.csv')):
#     _sp.append(pd.read_csv(filename))

# %%
spreads = pd.concat(_sp, ignore_index = True)
spreads['Symbol'] = tk

# %% [markdown]
# ## Initialize and find best parameters

# %%
# Initialize
backtest_test = backtest(_spread_data = spreads, _DTE = DTE, _stock_data = st)
backtest_test.all_spreads.shape
# Out:
# Done initializing! Time: 131.97 seconds.
# (55196482, 30)

# %%
'''
This part is for testing optimal expected OTM prob settings
You can define your desire spread width below in this block to check ROI in different OTM prob settings
'''

exp_win = [round(0.05 * i,2) for i in range(0,21)]
actual_win = list()
number_of_spreads = list()
average_profit = list()
cc = 0
while cc < len(exp_win)-1:
    def parms():
        min_Expected_Earn = None
        min_Expected_Earn_Ratio = None

        Sell_OTM_Prob_Range = [exp_win[cc], exp_win[cc+1]]
        Buy_OTM_Prob_Range = [exp_win[cc+1],None]

        min_Width = 2
        max_Width = 2

        max_trades_per_day = 1

        min_Premium = None
        max_Distance_to_Strike_Ratio = None

        Skip_Date = ['2018-2-9']

        parm = (min_Expected_Earn,min_Expected_Earn_Ratio,Sell_OTM_Prob_Range,Buy_OTM_Prob_Range,
                min_Width,max_Width,max_trades_per_day,min_Premium,max_Distance_to_Strike_Ratio,Skip_Date)

        print(Sell_OTM_Prob_Range)
        return parm
    
    
    backtest_test.set_parm(parms())
    backtest_test.find_spreads(_start_date = '2015-01-01', _end_date = None, 
                                                  _use_technical_indicator = False, _min_iv_ratio = None)
    filtered_spreads = backtest_test.spreads_satisfied
    number_of_spreads.append(len(filtered_spreads))
    actual_win.append(round( (filtered_spreads.Actual_Earn > 0).sum()/len(filtered_spreads),4))
    average_profit.append(round((filtered_spreads.Actual_Earn/ 
                                 abs(filtered_spreads.SellStrike - filtered_spreads.BuyStrike)).sum()/
                                len(filtered_spreads),2 ))
    cc += 1
# Out:
# [0.0, 0.05]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.37 seconds, CPU Time: 0.31 seconds.
# [0.05, 0.1]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.38 seconds, CPU Time: 0.38 seconds.
# [0.1, 0.15]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.35 seconds, CPU Time: 0.28 seconds.
# [0.15, 0.2]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.41 seconds, CPU Time: 0.34 seconds.
# [0.2, 0.25]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.45 seconds, CPU Time: 0.39 seconds.
# [0.25, 0.3]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.37 seconds, CPU Time: 0.2 seconds.
# [0.3, 0.35]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.42 seconds, CPU Time: 0.33 seconds.
# [0.35, 0.4]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.45 seconds, CPU Time: 0.33 seconds.
# [0.4, 0.45]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.45 seconds, CPU Time: 0.28 seconds.
# [0.45, 0.5]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 8.87 seconds, CPU Time: 1.44 seconds.
# [0.5, 0.55]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.4 seconds, CPU Time: 0.28 seconds.
# [0.55, 0.6]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.39 seconds, CPU Time: 0.25 seconds.
# [0.6, 0.65]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.4 seconds, CPU Time: 0.38 seconds.
# [0.65, 0.7]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.33 seconds, CPU Time: 0.2 seconds.
# [0.7, 0.75]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.35 seconds, CPU Time: 0.22 seconds.
# [0.75, 0.8]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.34 seconds, CPU Time: 0.3 seconds.
# [0.8, 0.85]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.33 seconds, CPU Time: 0.25 seconds.
# [0.85, 0.9]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.26 seconds, CPU Time: 0.36 seconds.
# [0.9, 0.95]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.36 seconds, CPU Time: 0.48 seconds.
# [0.95, 1.0]
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.3 seconds, CPU Time: 0.33 seconds.
# C:\Users\27270\AppData\Local\Temp\ipykernel_15612\1706151193.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   actual_win.append(round( (filtered_spreads.Actual_Earn > 0).sum()/len(filtered_spreads),4))
# C:\Users\27270\AppData\Local\Temp\ipykernel_15612\1706151193.py:37: RuntimeWarning: invalid value encountered in scalar divide
#   average_profit.append(round((filtered_spreads.Actual_Earn/

# %%
# Plot the result
fig,ax1 = plt.subplots()
fig.set_size_inches(16, 8, forward=True)

plot_x = [round(i+0.025,3) for i in exp_win]
plot_x.pop(-1)

ax1.plot(plot_x, actual_win, label = 'Actual Win Rate',marker='o')
ax1.set_xticks(exp_win)
ax1.set_xlabel("Expected OTM Probability (Expected Win Rate)", fontsize = 14)
ax1.set_ylabel("Actual Win Rate", color="black", fontsize=14)


# make a plot with different y-axis using second axis object
ax2 = ax1.twinx()

ax2.plot(plot_x, average_profit, label = 'Average ROI per trade', color = 'green',marker='o')
ax2.set_ylabel("Average ROI per trade", color="black", fontsize=14)

ax3 = ax1.twinx()
ax3.plot(plot_x, number_of_spreads, label = '# of Spreads', color = 'orange',marker='o')
ax3.set_ylabel("# of Spreads", color="black", fontsize=14)
ax3.spines['right'].set_position(('axes',-0.15))

ax1.legend(bbox_to_anchor=(0.14,1))
ax2.legend(bbox_to_anchor=(0.175,0.95))
ax3.legend(bbox_to_anchor=(0.123,0.9))

plt.title('DTE', DTE, 'Spreads Expected OTM Probability vs. Return plots', fontsize=16)
plt.show()

# %% [markdown]
# - From the plot above, seems like we need to set Expected OTM to be > 0.55 to achieve a greater than 75% actual win rate.

# %% [markdown]
# ## Set parameters and filter spreads for back testing

# %%
# Change the following parameters to create a filtering strategy.
def parms():
    min_Expected_Earn = None
    min_Expected_Earn_Ratio = 0 #<------ Enforce it to be > 0 to make only positive expectation trades.
    
    Sell_OTM_Prob_Range = [0.75,None] #<----- Setting desire expected OTM probability
    Buy_OTM_Prob_Range = [0.8,None]
    
    min_Width = 2 #<----- Setting the desire spread width
    max_Width = 2
    
    max_trades_per_day = 1
    
    min_Premium = None
    max_Distance_to_Strike_Ratio = None
    
    Skip_Date = ['2018-2-9']
    
    parm = (min_Expected_Earn,min_Expected_Earn_Ratio,Sell_OTM_Prob_Range,Buy_OTM_Prob_Range,
            min_Width,max_Width,max_trades_per_day,min_Premium,max_Distance_to_Strike_Ratio,Skip_Date)
    
    return parm

# %%
backtest_test.set_parm(parms())
backtest_test.find_spreads(_start_date = '2015-01-01', _end_date = None, _use_technical_indicator = False, _min_iv_ratio = None)
backtest_test.spreads_satisfied[op_cols2]

print('Expected Win Rate:')
print(round(np.mean(backtest_test.spreads_satisfied.Sell_OTM_Prob),4))
print('Actual Win Rate:')
backtest_test.win_rate()
# Out:
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-27 00:00:00!
# Total Time: 1.28 seconds, CPU Time: 0.22 seconds.
# Expected Win Rate:
# 0.9862
# Actual Win Rate:
# Total: 316 satisfied spreads, win rate: 0.981
# 0.981

# %% [markdown]
# ## Set porfolio and backtest

# %%
def define_portfolio():
    funds = 10000
    take_profit = None
    stop_loss = 3
    position_size = 0.3 # % of funds allocated per trade 
    max_position = 0.7
    
    return (funds, take_profit, stop_loss, position_size, max_position)


backtest_test.set_portfolio(define_portfolio(), _backtest_start_date = None , _backtest_end_date = None)

# %%
backtest_test.generate_results()
backtest_test.report()
# Out:
# Done Done Preparing for Backtesting 762.69 seconds
# Done backtesting: 763.83 seconds
# Year 2015 Return: 276.0 Starting: 10000
# Year 2016 Return: 353.0 Starting: 10276.0
# Year 2017 Return: 465.0 Starting: 10628.999999999998
# Year 2018 Return: 102.0 Starting: 11093.999999999996
# Year 2019 Return: 476.0 Starting: 11195.999999999996
# Year 2020 Return: 777.0 Starting: 11671.999999999995
# Year 2021 Return: 2245.0 Starting: 12448.999999999993
# Year 2022 Return: -71.0 Starting: 14693.999999999989
# Year 2023 Return: 17.0 Starting: 14622.999999999989
# [0.0276, 0.0344, 0.0437, 0.0092, 0.0425, 0.0666, 0.1803, -0.0048, 0.0012]
# std: 0.052571407052752275
# Report:
#
# Number of Positions: 291
# Win Rate: 0.8144
# Sharpe Ratio: 0.85
# Total Return: 4640.0
# Total Return Ratio: 0.464
# Funds not utilized: 3013.0
# Max Collateral: 4200.0
# Max Drawdown: 0.048 Date: 2021-12-01 00:00:00 - 2022-02-14 00:00:00
# Max Individual Loss: -272.0 id: 20809458
# Max Individual Gain: 170.0 id: 24874435
# Average Collateral: 1874.23
# Average Gain: 15.95
# Average Annual Return: 0.04
# Average Return Ratio: 0.0088
# Average Expectation Return Ratio: 0.0054
# Average Expected Win Rate: 0.99

# %%
# Display Trade history
trades_history = backtest_test.trades_history
trades_history.style.set_properties(subset=['Option Info: ((Sell Strike, buy Strike, Expiry), Quantity, Collateral, Premium, idx)'], **{'width': '300px'})
# Out:
# <style type="text/css">
# #T_a9158_row0_col7, #T_a9158_row1_col7, #T_a9158_row2_col7, #T_a9158_row3_col7, #T_a9158_row4_col7, #T_a9158_row5_col7, #T_a9158_row6_col7, #T_a9158_row7_col7, #T_a9158_row8_col7, #T_a9158_row9_col7, #T_a9158_row10_col7, #T_a9158_row11_col7, #T_a9158_row12_col7, #T_a9158_row13_col7, #T_a9158_row14_col7, #T_a9158_row15_col7, #T_a9158_row16_col7, #T_a9158_row17_col7, #T_a9158_row18_col7, #T_a9158_row19_col7, #T_a9158_row20_col7, #T_a9158_row21_col7, #T_a9158_row22_col7, #T_a9158_row23_col7, #T_a9158_row24_col7, #T_a9158_row25_col7, #T_a9158_row26_col7, #T_a9158_row27_col7, #T_a9158_row28_col7, #T_a9158_row29_col7, #T_a9158_row30_col7, #T_a9158_row31_col7, #T_a9158_row32_col7, #T_a9158_row33_col7, #T_a9158_row34_col7, #T_a9158_row35_col7, #T_a9158_row36_col7, #T_a9158_row37_col7, #T_a9158_row38_col7, #T_a9158_row39_col7, #T_a9158_row40_
T_a9158_row159_col7, #T_a9158_row160_col7, #T_a9158_row161_col7, #T_a9158_row162_col7, #T_a9158_row163_col7, #T_a9158_row164_col7, #T_a9158_row165_col7, #T_a9158_row166_col7, #T_a9158_row167_col7, #T_a9158_row168_col7, #T_a9158_row169_col7, #T_a9158_row170_col7, #T_a9158_row171_col7, #T_a9158_row172_col7, #T_a9158_row173_col7, #T_a9158_row174_col7, #T_a9158_row175_col7, #T_a9158_row176_col7, #T_a9158_row177_col7, #T_a9158_row178_col7, #T_a9158_row179_col7, #T_a9158_row180_col7, #T_a9158_row181_col7, #T_a9158_row182_col7, #T_a9158_row183_col7, #T_a9158_row184_col7, #T_a9158_row185_col7, #T_a9158_row186_co ...

# %%
# trades_history.to_csv('saved_trades_history\\DTE7_trade_history_capped_stoploss.csv')

# %% [markdown]
# ## ==================================================================
# ## Codes below are still under development
# ## ==================================================================

# %% [markdown]
# ## Results with both technical indicators and parameters

# %%
#initialize
backtest_class_with_TA = backtest(_spread_data = spreads, _DTE = DTE, _stock_data = st)
# Out:
# Done initializing! Time: 28.45 seconds.

# %%
backtest_class_with_TA.set_parm(parms())
backtest_class_with_TA.find_spreads(_use_technical_indicator = True, _min_iv_ratio = 0.8, _start_date = '2015-01-01')

print('Expected Win Rate:')
print(round(np.mean(backtest_class_with_TA.spreads_satisfied.Sell_OTM_Prob),4))
print('Actual Win Rate:')
backtest_class_with_TA.win_rate()
# Out:
# Done searching spreads from 2015-01-01 00:00:00 to 2023-01-06 00:00:00!
# Total Time: 1.55 seconds, CPU Time: 0.31 seconds.
# Total: 267 satisfied spreads, win rate: 0.9888
# 0.9888

# %%
backtest_class_with_TA.set_portfolio(define_portfolio(), _backtest_start_date = None , _backtest_end_date = None)
backtest_class_with_TA.generate_results()
# Out:
# Done Done Preparing for Backtesting 121.21 seconds
# Done backtesting: 122.15 seconds

# %%
backtest_class_with_TA.report()
# Out:
# Year 2015 Return: -299.0000000000015 Starting: 10066.0
# Year 2016 Return: -39.0 Starting: 9581.0
# Year 2017 Return: 869.999999999997 Starting: 9719.0
# Year 2018 Return: 851.9999999999972 Starting: 10636.999999999996
# Year 2019 Return: 1260.9999999999973 Starting: 11551.999999999995
# Year 2020 Return: 160.00000000000156 Starting: 12744.999999999993
# Year 2021 Return: 5088.999999999994 Starting: 12384.999999999995
# Year 2022 Return: 539.9999999999994 Starting: 18071.999999999993
# [-0.0297, -0.0041, 0.0895, 0.0801, 0.1092, 0.0126, 0.4109, 0.0299]
# std: 0.13046602048043007
# Report:
#
# Number of Positions: 156
# Win Rate: 0.8718
# Sharpe Ratio: 0.67
# Total Return: 8434.0
# Total Return Ratio: 0.8434
# Funds not utilized: 1.999999999994543
# Max Collateral: 18300.0
# Max Drawdown: 0.084 Date: 2020-02-27 00:00:00
# Max Individual Loss: -804.0 id: 1167367
# Max Individual Gain: 351.0 id: 5184583
# Average Collateral: 9515.06
# Average Gain: 54.06
# Average Annual Return: 0.09
# Average Return Ratio: 0.0056
# Average Expectation Return Ratio: 0.0062
row100_col7, #T_04b1b_row101_col7, #T_04b1b_row102_col7, #T_04b1b_row103_col7, #T_04b1b_row104_col7, #T_04b1b_row105_col7, #T_04b1b_row106_col7, #T_04b1b_row107_col7, #T_04b1b_row108_col7, #T_04b1b_row109_col7, #T_04b1b_row110_col7, #T_04b1b_row111_col7, #T_04b1b_row112_col7, #T_04b1b_row113_col7, #T_04b1b_row114_col7, #T_04b1b_row115_col7, #T_04b1b_row116_col7, #T_04b1b_row117_col7, #T_04b1b_row118_col7, #T_04b1b_row119_col7, #T_04b1b_row120_col7, #T_04b1b_row121_col7, #T_04b1b_row122_col7, #T_04b1b_row123_col7, #T_04b1b_row124_col7, #T_04b1b_row125_col7, #T_04b1b_row126_col7, #T_04b1b_row127_col7, #T_04b1b_row128_col7, #T_04b1b_row129_col7, #T_04b1b_row130_col7, #T_04b1b_row131_col7, #T_04b1b_row132_col7, #T_04b1b_row133_col7, #T_04b1b_row134_col7, #T_04b1b_row135_col7, #T_04b1b_row136_col7, #T_04b1b_row137_col7, #T_04b1b_row138_col7, #T_04b1b_row139_col7, #T_04b1b_row140_col7, #T_04b1b_row141_col7, #T_04b1b_row142_col7, #T_04b1b_row143_col7, #T_04b1b_row144_col7, #T_04b1b_row145_col7, #T_04b1b_row146_col7, #T_04b1b_row147_col7, #T_04b1b_row148_col7, #T_04b1b_row149_col7, #T_04b1b_row150_col7, #T_04b1b_row151_col7, #T_04b1b_row152_col7, #T_04b1b_row153_col7, #T_04b1b_row154_col7, #T_04b1b_row155_col7, #T_04b1b_row156_col7, #T_04b1b_row157_col7, #T_04b1b_row158_col7, #T_04b1b_row159_col7, #T_04b1b_row160_col7, #T_04b1b_row161_col7, #T_04b1b_row162_col7, #T_04b1b_row163_col7, #T_04b1b_row164_col7, #T_04b1b_row165_col7, #T_04b1b_row166_col7, #T_04b1b_row167_col7, #T_04b1b_row168_col7, #T_04b1b_row169_col7, #T_04b1b_row170_col7, #T_04b1b_row171_col7, #T_04b1b_row172_col7, #T_04b1b_row173_col7, #T_04b1b_row174_col7, #T_04b1b_row175_col7, #T_04b1b_row176_col7, #T_04b1b_row177_col7, #T_04b1b_row178_col7, #T_04b1b_row179_col7, #T_04b1b_row180_col7, #T_04b1b_row181_col7, #T_04b1b_row182_col7, #T_04b1b_row183_col7, #T_04b1b_row184_col7, #T_04b1b_row185_col7, #T_04b1b_row186_co ...
#   width: 300px;
# }
# </style>
# <table id="T_04b1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04b1b_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_04b1b_level0_col1" class="col_heading level0 col1" >Spreads Type</th>
#       <th id="T_04b1b_level0_col2" class="col_heading level0 col2" >Spread index</th>
#       <th id="T_04b1b_level0_col3" class="col_heading level0 col3" >Trades Type</th>
#       <th id="T_04b1b_level0_col4" class="col_heading level0 col4" >Initial Funds</th>
#       <th id="T_04b1b_level0_col5" class="col_heading level0 col5" >Funds After</th>
#       <th id="T_04b1b_level0_col6" class="col_heading level0 col6" >Stock Price</th>
#       <th id="T_04b1b_level0_col7" class="col_heading level0 col7" >Option Info: ((Sell Strike, buy Strike, Expiry), Quantity, Collateral, Premium, idx)</th>
#       <th id="T_04b1b_level0_col8" class="col_heading level0 col8" >Profit</th>
#       <th id="T_04b1b_level0_col9" class="col_heading level0 col9" ># of strategies holding</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04b1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04b1b_row0_col0" class="data row0 col0" >2015-02-13

# %% [markdown]
# ## Some interesting plots

# %%
class_st = backtest_class_with_TA.stock_data
class_st = class_st[1000:2000]
fig,ax1 = plt.subplots()

fig.set_size_inches(16, 8, forward=True)
# make a plot
ax1.plot(class_st.Date, class_st.Close,color="grey")
# set x-axis label
ax1.set_xlabel("Year", fontsize = 14)
# set y-axis label
ax1.set_ylabel("Stock",
              color="black",
              fontsize=14)


# make a plot with different y-axis using second axis object
ax2 = ax1.twinx()
ax2.plot(class_st.dropna().Date, class_st.dropna().EMA_50,color="red")
ax2.plot(class_st.dropna().Date, class_st.dropna().EMA_DTE,color="green")
ax2.set_ylabel("Spreads",color="black")
plt.title("Stock & EMA",fontsize=16)
ax1.legend(['Stock'],loc='center left')
ax2.legend(['EMA_50', 'EMA_14'],loc='center right')

plt.show()

# %%
# Crossover plot

df_ = backtest_class_with_TA.stock_data

df_.index = df_.Date
plt.figure(figsize = (20,10))
# plot close price, short-term and long-term moving averages 
df_['Close'].plot(color = 'k', label= 'Price') 
df_['EMA_DTE'].plot(color = 'b',label = 'DTE SMA') 
df_['EMA_50'].plot(color = 'g', label = '50-day SMA')
# plot ‘buy’ signals
plt.plot(df_[df_['Trend_Reversal'] == 1].index, 
         df_['EMA_50'][df_['Trend_Reversal'] == 1], 
         '^', markersize = 15, color = 'g', label = 'buy')
# plot ‘sell’ signals
plt.plot(df_[df_['Trend_Reversal'] == -1].index, 
         df_['EMA_50'][df_['Trend_Reversal'] == -1], 
         'v', markersize = 15, color = 'r', label = 'sell')
plt.ylabel('Price', fontsize = 15 )
plt.xlabel('Date', fontsize = 15 )
plt.title('SPY', fontsize = 20)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize = (18,10))
plt.title('SPY 150d Volitality')
plt.plot(backtest_class_with_TA.stock_data.Date, backtest_class_with_TA.stock_data.Hist_Volatility)

# %%
class_st = backtest_class_with_TA.stock_data
putt_ = backtest_class_with_TA.all_spreads
fig,ax1 = plt.subplots()

fig.set_size_inches(16, 8, forward=True)
# make a plot
ax1.plot(class_st.Date, class_st.Hist_Volatility,color="grey")
# set x-axis label
ax1.set_xlabel("Year", fontsize = 14)
# set y-axis label
ax1.set_ylabel("Stock",
              color="black",
              fontsize=14)
# ax1.set_yticks([0.05* i for i in range(10)])

# make a plot with different y-axis using second axis object
ax2 = ax1.twinx()

piv_avg7 = putt_.ATM_IV.rolling(50).mean() 

# ax2.plot(putt_.QUOTE_TIME_EST,piv_avg7,color="red")
ax2.plot(putt_.QuoteDate, piv_avg7,color="green")


ax2.set_ylabel("Spreads",color="black")
plt.title("Hist Vol & Implied Vol",fontsize=16)
ax1.legend(['Hist Vol'],loc='center left')
ax2.legend(['Put Implied Vol', 'Call Implied Vol'],loc='center right')

a,b = 0,1.2
ax1.set_ylim(a,b)
ax2.set_ylim(a,b)

plt.show()
